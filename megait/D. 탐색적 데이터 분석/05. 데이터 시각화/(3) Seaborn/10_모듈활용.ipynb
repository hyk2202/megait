# %% [markdown]
# # 모듈 활용 테스트
#
# ## #01. 준비작업
#
# ### [1] 패키지 참조

# %%
import sys
import os
work_path = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
sys.path.append(work_path)

from helper.plot import *
from helper.util import *

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
origin = my_read_excel("https://data.hossam.kr/edadata/grade.xlsx", index_col='이름', info=False)

# %% [markdown]
# ### [3] 일부 변수를 명목형으로 변환하기

# %%
df = set_category(origin, '학년', '성별')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 철수 to 석영
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   학년      9 non-null      category
#  1   성별      9 non-null      category
#  2   국어      9 non-null      int64
#  3   영어      9 non-null      int64
#  4   수학      9 non-null      int64
#  5   과학      9 non-null      int64
# dtypes: category(2), int64(4)
# memory usage: 706.0+ bytes

# %% [markdown]
# ## #02. 상자그림

# %%
my_boxplot(df)

# %%
my_boxplot(df, orient='h')

# %%
my_boxplot(df[['국어']], orient='h', figsize=(5, 2), dpi=100)

# %% [markdown]
# ## #03. 히스토그램

# %%
my_histplot(df, '국어')

# %%
my_histplot(df, xname = '국어', hue='성별')

# %%
my_histplot(df, '국어', bins=3, kde=False)

# %% [markdown]
# ## #04. 산점도 그래프

# %%
my_scatterplot(df, '국어', '수학')

# %%
my_scatterplot(df, '국어', '수학', hue='성별')

# %%
(len(df['국어']),len(df['수학']))
# Out:
# (9, 9)

# %%
my_regplot(df, '국어', '수학')

# %%
my_lmplot(df, '국어', '영어', hue='성별', dpi=100)

# %%
my_pairplot(df, hue='성별')

# %%
my_pairplot(df, hue='성별', diag_kind='kde')

# %% [markdown]
# ## #05. 막대그래프
#
# ### [1] 빈도 막대 그래프

# %%
my_countplot(df, '학년', hue='성별')

# %% [markdown]
# ### [2] 평균 막대 그래프

# %%
my_barplot(df, '학년', '국어', hue='성별')

# %% [markdown]
# ## #06. 그 밖의 형태
#
# ### [1] 바이올린 플롯

# %%
my_violinplot(df, '학년', '국어')

# %% [markdown]
# ### [2] 포인트 플롯

# %%
my_pointplot(df, '학년', '국어')

# %% [markdown]
# ### [3] 조인트 플롯

# %%
my_jointplot(df, '국어', '수학')

# %% [markdown]
# ### [4] 히트맵

# %%
my_heatmap(df[['국어', '수학', '영어']])

# %%
from helper.plot import *

# %% [markdown]
# ### [5] 군집 시각화

# %%
my_convex_hull(df, '국어', '수학', hue='성별')
