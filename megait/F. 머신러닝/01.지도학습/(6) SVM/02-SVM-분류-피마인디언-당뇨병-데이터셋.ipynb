# %% [markdown]
# # SVM 분류 - 피마 인디언 당뇨병 데이터 셋
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import warnings
warnings.filterwarnings(action='ignore')

# Intel SKlearn 하드웨어 가속 패치 설정
from sklearnex import patch_sklearn
patch_sklearn()

from helper.util import *
from helper.plot import *
from helper.analysis import *
from helper.classification import *
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
origin = my_read_excel("https://data.hossam.kr/mldata/pima_indians_diabetes.xlsx", categories=['Outcome'], info=False)

# %% [markdown]
# ## #02. 데이터 전처리
#
# ### [1] 이전 예제에서 수립한 전처리 전략 재현
#
# 1. `0`값을 포함해서는 안되는 변수에 대해 평균으로 대체

# %%
# 정제 대상 필드명
zero_features = ['Glucose', 'BloodPressure','SkinThickness','Insulin','BMI']

# `0`값을 결측치로 대체후 평균으로 다시 치환
df = origin.copy()
df[zero_features] = df[zero_features].replace(0, np.nan)
df2 = my_replace_missing_value(df)

# %% [markdown]
# ## #03. SVM 분류 적용
#
# ### [1] 훈련, 검증 데이터 분리

# %%
df2['Outcome'] = df2['Outcome'].astype('int')

x_train, x_test, y_train, y_test = my_train_test_split(df2, yname='Outcome', test_size=0.2, scalling=False)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((614, 8), (154, 8), (614,), (154,))

# %% [markdown]
# ### [2] 분류 알고리즘 적용

# %%
my_svc_classification(x_train, y_train, x_test, y_test)
# Out:
# n_jobs를 허용하지 않음
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [교차검증 TOP5]
# +----+----------+----------+-----+-------------------+
# |    | kernel   |   degree |   C |   mean_test_score |
# |----+----------+----------+-----+-------------------|
# | 17 | poly     |        2 |  10 |          0.770412 |
# |  9 | poly     |        2 |   1 |          0.763894 |
# | 19 | poly     |        3 |  10 |          0.759016 |
# | 22 | rbf      |        5 |  10 |          0.759003 |
# | 20 | rbf      |        4 |  10 |          0.759003 |
# +----+----------+----------+-----+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.778502 |     0.772727 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |      0.74026 |     0.794872 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.542857 |     0.534483 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout) |    0.0990099 |    0.0833333 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)       |      0.90099 |     0.916667 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score          |     0.626374 |     0.639175 | 정밀도와 재현율의 조화평균                                |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [학습곡선]
# SVC(C=10, degree=2, kernel='poly')
