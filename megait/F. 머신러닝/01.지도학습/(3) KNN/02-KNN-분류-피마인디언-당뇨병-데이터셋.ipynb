# %% [markdown]
# # KNN 분류 - 피마 인디언 당뇨병 데이터 셋
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import warnings
warnings.filterwarnings(action='ignore')

from helper.util import *
from helper.plot import *
from helper.analysis import *
from helper.classification import *

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
origin = my_read_excel("https://data.hossam.kr/mldata/pima_indians_diabetes.xlsx", categories=['Outcome'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    category
# dtypes: category(1), float64(2), int64(6)
# memory usage: 49.0 KB
# None
#
# 데이터프레임 상위 5개 행
# +----+---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |    |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |----+---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |  0 |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |  1 |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |  2 |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |  3 |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# |  4 |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# +----+---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
#
# 데이터프레임 하위 5개 행
# +-----+---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |     |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |-----+---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# | 763 |            10 |       101 |              76 |              48 |       180 |  32.9 |                      0.171 |    63 |         0 |
# | 764 |             2 |       122 |              70 |              27 |         0 |  36.8 |                       0.34 |    27 |         0 |
# | 765 |             5 |       121 |              72 |              23 |       112 |  26.2 |                      0.245 |    30 |         0 |
# | 766 |             1 |       126 |              60 |               0 |         0 |  30.1 |                      0.349 |    47 |         1 |
# | 767 |             1 |        93 |              70 |              31 |         0 |  30.4 |                      0.315 |    23 |         0 |
# +-----+---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
#
# 기술통계
# +--------------------------+---------+----------+----------+-------+---------+--------+---------+-------+-------+
# |                          |   count |     mean |      std |   min |     25% |    50% |     75% |   max |   nan |
# |--------------------------+---------+----------+----------+-------+---------+--------+---------+-------+-------|
# | Pregnancies              |     768 |  3.84505 |  3.36958 |     0 |       1 |      3 |       6 |    17 |     0 |
# | Glucose                  |     768 |  120.895 |  31.9726 |     0 |      99 |    117 |  140.25 |   199 |     0 |
# | BloodPressure            |     768 |  69.1055 |  19.3558 |     0 |      62 |     72 |      80 |   122 |     0 |
# | SkinThickness            |     768 |  20.5365 |  15.9522 |     0 |       0 |     23 |      32 |    99 |     0 |
# | Insulin                  |     768 |  79.7995 |  115.244 |     0 |       0 |   30.5 |  127.25 |   846 |     0 |
# | BMI                      |     768 |  31.9926 |  7.88416 |     0 |    27.3 |     32 |    36.6 |  67.1 |     0 |
# | DiabetesPedigreeFunction |     768 | 0.471876 | 0.331329 | 0.078 | 0.24375 | 0.3725 | 0.62625 |  2.42 |     0 |
# | Age                      |     768 |  33.2409 |  11.7602 |    21 |      24 |     29 |      41 |    81 |     0 |
# +--------------------------+---------+----------+----------+-------+---------+--------+---------+-------+-------+
#
# 카테고리 정보
# +----+---------+
# |    |   count |
# |----+---------|
# |  0 |     500 |
# |  1 |     268 |
# +----+---------+

# %% [markdown]
# ## #02. 데이터 전처리
#
# ### [1] 이전 예제에서 수립한 전처리 전략 재현
#
# 1. `0`값을 포함해서는 안되는 변수에 대해 평균으로 대체
#
# #### (1) 정제 대상 필드명

# %%
zero_features = ['Glucose', 'BloodPressure','SkinThickness','Insulin','BMI']

# %% [markdown]
# #### (2) `0`값을 결측치로 대체후 평균으로 다시 치환

# %%
df = origin.copy()
df[zero_features] = df[zero_features].replace(0, np.nan)
df2 = my_replace_missing_value(df)

# %% [markdown]
# #### (3) 결과 확인

# %%
total_count = len(origin)

for feature in zero_features:
    zero_count = origin[origin[feature] == 0][feature].count()
    print('{0} 0 건수는 {1}, 퍼센트는 {2:.2f} %'.format(feature, zero_count, 100*zero_count/total_count))

print("---" * 30)

for feature in zero_features:
    zero_count = df2[df2[feature] == 0][feature].count()
    print('{0} 0 건수는 {1}, 퍼센트는 {2:.2f} %'.format(feature, zero_count, 100*zero_count/total_count))
# Out:
# Glucose 0 건수는 5, 퍼센트는 0.65 %
# BloodPressure 0 건수는 35, 퍼센트는 4.56 %
# SkinThickness 0 건수는 227, 퍼센트는 29.56 %
# Insulin 0 건수는 374, 퍼센트는 48.70 %
# BMI 0 건수는 11, 퍼센트는 1.43 %
# ------------------------------------------------------------------------------------------
# Glucose 0 건수는 0, 퍼센트는 0.00 %
# BloodPressure 0 건수는 0, 퍼센트는 0.00 %
# SkinThickness 0 건수는 0, 퍼센트는 0.00 %
# Insulin 0 건수는 0, 퍼센트는 0.00 %
# BMI 0 건수는 0, 퍼센트는 0.00 %

# %% [markdown]
# ## #03. KNN 분류 적용
#
# ### [1] 훈련, 검증 데이터 분리

# %%
df2['Outcome'] = df2['Outcome'].astype('int')

x_train, x_test, y_train, y_test = my_train_test_split(df2, yname='Outcome', test_size=0.2, scalling=False)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((614, 8), (154, 8), (614,), (154,))

# %% [markdown]
# ### [2] 분류 알고리즘 적용

# %%
my_knn_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-----------+---------------+-----------+-------------------+
# |    | metric    |   n_neighbors | weights   |   mean_test_score |
# |----+-----------+---------------+-----------+-------------------|
# |  9 | manhattan |             5 | distance  |          0.728055 |
# | 11 | manhattan |             7 | distance  |          0.726469 |
# |  8 | manhattan |             5 | uniform   |          0.723151 |
# | 10 | manhattan |             7 | uniform   |          0.721551 |
# |  5 | euclidean |             7 | distance  |          0.718353 |
# |  3 | euclidean |             5 | distance  |          0.716727 |
# |  2 | euclidean |             5 | uniform   |          0.715101 |
# |  4 | euclidean |             7 | uniform   |          0.715087 |
# |  6 | manhattan |             3 | uniform   |          0.710183 |
# |  7 | manhattan |             3 | distance  |           0.70857 |
# |  0 | euclidean |             3 | uniform   |          0.701986 |
# |  1 | euclidean |             3 | distance  |           0.70036 |
# +----+-----------+---------------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
# |                         |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------------+--------------+--------------+-----------------------------------------------------------|
# | 의사결정계수(Pseudo R2) |            1 |     -2.03822 | 로지스틱회귀의 성능 측정 지표로, 1에 가까울수록 좋은 모델 |
# | 정확도(Accuracy)        |            1 |      0.74026 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision)       |            1 |     0.695652 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)          |            1 |     0.551724 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | 위양성율(Fallout)       |            0 |     0.145833 | 실제 음성(FP,TN) 중 양성(FP)으로 잘못 예측한 비율         |
# | 특이성(TNR)             |            1 |     0.854167 | 실제 음성(FP,TN) 중 음성(TN)으로 정확히 예측한 비율       |
# | F1 Score                |            1 |     0.615385 | 정밀도와 재현율의 조화평균                                |
# | AUC                     |            1 |     0.815104 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [Roc Curve]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [학습곡선]
# KNeighborsClassifier(metric='manhattan', n_jobs=-1, weights='distance')
