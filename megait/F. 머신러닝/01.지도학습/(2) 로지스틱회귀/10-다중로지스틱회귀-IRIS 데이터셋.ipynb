# %% [markdown]
# # 다중로지스틱회귀 (IRIS 데이터셋)
#
# 종속변수가 세 개 이상의 분류를 갖는 로지스틱회귀.
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import warnings
warnings.filterwarnings(action='ignore')

from helper.util import *
from helper.plot import *
from helper.analysis import *
from helper.classification import *

# %% [markdown]
# ### [2] 데이터 가져오기
#
# 붓꽃(iris)은 관상용으로도 재배되는 아름다운 꽃이며 크기와 색상이 다른 많은 종이 있다.
#
# 세 붓꽃 종의 이름은 `Versicolor`, `Setosa`, `Virginica`이며 각 종에 따라 꽃받침의 길이와 너비, 꽃잎의 길이와 너비가 약간씩 차이가 난다.
#
# > https://www.kaggle.com/datasets/uciml/iris
#
# ![img](res/iris.png)

# %%
origin = my_read_excel("https://data.hossam.kr/mldata/iris.xlsx", categories=['Species'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB
# None
#
# 데이터프레임 상위 5개 행
# +----+----------------+---------------+----------------+---------------+-----------+
# |    |   Sepal.Length |   Sepal.Width |   Petal.Length |   Petal.Width | Species   |
# |----+----------------+---------------+----------------+---------------+-----------|
# |  0 |            5.1 |           3.5 |            1.4 |           0.2 | setosa    |
# |  1 |            4.9 |             3 |            1.4 |           0.2 | setosa    |
# |  2 |            4.7 |           3.2 |            1.3 |           0.2 | setosa    |
# |  3 |            4.6 |           3.1 |            1.5 |           0.2 | setosa    |
# |  4 |              5 |           3.6 |            1.4 |           0.2 | setosa    |
# +----+----------------+---------------+----------------+---------------+-----------+
#
# 데이터프레임 하위 5개 행
# +-----+----------------+---------------+----------------+---------------+-----------+
# |     |   Sepal.Length |   Sepal.Width |   Petal.Length |   Petal.Width | Species   |
# |-----+----------------+---------------+----------------+---------------+-----------|
# | 145 |            6.7 |             3 |            5.2 |           2.3 | virginica |
# | 146 |            6.3 |           2.5 |              5 |           1.9 | virginica |
# | 147 |            6.5 |             3 |            5.2 |             2 | virginica |
# | 148 |            6.2 |           3.4 |            5.4 |           2.3 | virginica |
# | 149 |            5.9 |             3 |            5.1 |           1.8 | virginica |
# +-----+----------------+---------------+----------------+---------------+-----------+
#
# 기술통계
# +--------------+---------+---------+----------+-------+-------+-------+-------+-------+-------+
# |              |   count |    mean |      std |   min |   25% |   50% |   75% |   max |   nan |
# |--------------+---------+---------+----------+-------+-------+-------+-------+-------+-------|
# | Sepal.Length |     150 | 5.84333 | 0.828066 |   4.3 |   5.1 |   5.8 |   6.4 |   7.9 |     0 |
# | Sepal.Width  |     150 | 3.05733 | 0.435866 |     2 |   2.8 |     3 |   3.3 |   4.4 |     0 |
# | Petal.Length |     150 |   3.758 |   1.7653 |     1 |   1.6 |  4.35 |   5.1 |   6.9 |     0 |
# | Petal.Width  |     150 | 1.19933 | 0.762238 |   0.1 |   0.3 |   1.3 |   1.8 |   2.5 |     0 |
# +--------------+---------+---------+----------+-------+-------+-------+-------+-------+-------+
#
# 카테고리 정보
# +------------+---------+
# |            |   count |
# |------------+---------|
# | setosa     |      50 |
# | versicolor |      50 |
# | virginica  |      50 |
# +------------+---------+

# %% [markdown]
# ## #02. 탐색적 데이터 분석
#
# ### [1] 품종에 따른 데이터 분포 확인
#
# 이항분류의 경우 커널밀도 함수등으로 종속변수 따른 데이터 분포를 확인
#
# 다항분류의 경우 산점도 그래프를 통해 종속변수에 따른 데이터 군집이 존재 하는지를 확인

# %%
names = origin.columns[:-1]
size = len(names)

for i in range(0, size):
    j = (i + 1) % size
    #print(i, j)
    #print(names[i], names[j])
    my_scatterplot(origin, xname=names[i], yname=names[j], hue='Species')

# %% [markdown]
# > 명확하게 품종에 따라 군집이 형성되어 있는 것을 확인할 수 있다.

# %% [markdown]
# ### [2] 상자그림 확인

# %%
my_boxplot(origin)

# %% [markdown]
# > 데이터 스케일링은 필요해 보인다.

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### [1] 데이터 스케일링

# %%
df = my_standard_scaler(origin, yname='Species')
my_boxplot(df)

# %% [markdown]
# > 이상치의 수가 크지 않고, 종속변수가 50, 50, 50으로 균형을 이루고 있으므로 이 균형을 유지하기 위해 이상치 제거는 하지 않도록 함.

# %% [markdown]
# ### [2] 종속변수 라벨링

# %%
df2 = my_labelling(df, 'Species')
my_pretty_table(df2.head())
# Out:
# +----+----------------+---------------+----------------+---------------+-----------+
# |    |   Sepal.Length |   Sepal.Width |   Petal.Length |   Petal.Width |   Species |
# |----+----------------+---------------+----------------+---------------+-----------|
# |  0 |      -0.900681 |         1.019 |       -1.34023 |      -1.31544 |         0 |
# |  1 |       -1.14302 |     -0.131979 |       -1.34023 |      -1.31544 |         0 |
# |  2 |       -1.38535 |      0.328414 |       -1.39706 |      -1.31544 |         0 |
# |  3 |       -1.50652 |     0.0982173 |       -1.28339 |      -1.31544 |         0 |
# |  4 |       -1.02185 |        1.2492 |       -1.34023 |      -1.31544 |         0 |
# +----+----------------+---------------+----------------+---------------+-----------+

# %% [markdown]
# ## #04. 로지스틱 회귀 모형
#
# ### [1] 데이터 분할

# %%
x_train, x_test, y_train, y_test = my_train_test_split(df2, yname='Species', test_size=0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %% [markdown]
# ### [2] 로지스틱 회귀 구현

# %%
my_logistic_classification(x_train, y_train, x_test, y_test)
# Out:
# [교차검증]
# +----+-------+-----------+-------------------+
# |    |     C | penalty   |   mean_test_score |
# |----+-------+-----------+-------------------|
# | 13 |    10 | l2        |          0.966667 |
# | 16 |   100 | l2        |          0.966667 |
# | 10 |     1 | l2        |          0.958333 |
# |  7 |   0.1 | l2        |          0.908333 |
# |  4 |  0.01 | l2        |          0.858333 |
# |  1 | 0.001 | l2        |          0.508333 |
# +----+-------+-----------+-------------------+
#
# [분류분석 성능평가]
# +-------------------+--------------+--------------+-----------------------------------------------------------+
# |                   |   훈련데이터 |   검증데이터 | 설명                                                      |
# |-------------------+--------------+--------------+-----------------------------------------------------------|
# | 정확도(Accuracy)  |     0.991667 |     0.966667 | 예측 결과(TN,FP,TP,TN)가 실제 결과(TP,TN)와 일치하는 정도 |
# | 정밀도(Precision) |     0.991667 |     0.952381 | 양성으로 예측한 결과(TP,FP) 중 실제 양성(TP)인 비율       |
# | 재현율(Recall)    |     0.992424 |     0.969697 | 실제 양성(TP,FN) 중 양성(TP)으로 예측한 비율              |
# | F1 Score          |     0.991949 |     0.958486 | 정밀도와 재현율의 조화평균                                |
# | AUC(ovo)          |            1 |     0.994949 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# | AUC(ovr)          |            1 |      0.99609 | ROC Curve의 밑면적으로, 1에 가까울수록 좋은 모델          |
# +-------------------+--------------+--------------+-----------------------------------------------------------+
#
# [혼동행렬]
# [ROC/PR Curve]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 my_logistic_classification(x_train, y_train, x_test, y_test)
#
# File c:\Users\hyk\Desktop\수업\megait\helper\classification.py:73, in my_logistic_classification(x_train, y_train, x_test, y_test, cv, learning_curve, report, figsize, dpi, sort, params)
#      70 #------------------------------------------------------
#      71 # 성능평가
#      72 if x_test is not None and y_test is not None:
# ---> 73     my_classification_result(estimator, x_train=x_train, y_train=y_train, x_test=x_test, y_test=y_test, learning_curve=learning_curve, cv=cv, figsize=figsize, dpi=dpi)
#      74 else:
#      75     my_classification_result(estimator, x_train=x_train, y_train=y_train, learning_curve=learning_curve, cv=cv, figsize=figsize, dpi=dpi)
#
# File c:\Users\hyk\Desktop\수업\megait\helper\classification.py:251, in my_classification_result(estimator, x_train, y_train, x_test, y_test, conf_matrix, roc_curve, pr_curve, learning_curve, cv, figsize, dpi)
#     249 print("\n[ROC/PR Curve]")
#     250 if x_test is not None and y_test is not None:
# --> 251     my_roc_pr_curve(y_test, y_test_pred_proba_1, figsize=figsize, dpi=dpi)
#     252 else:
#     253     my_roc_pr_curve(y_train, y_train_pred_proba_1, figsize=figsize, dpi=dpi)
#
# File c:\Users\hyk\Desktop\수업\megait\helper\plot.py:830, in my_roc_pr_curve(y, y_proba, figsize, dpi, callback)
#     827 fig, ax = plt.subplots(1, 2, figsize=figsize, dpi=dpi)
#     829 # ROC Curve
# --> 830 fpr, tpr, thresholds = roc_curve(y, y_proba)
#     831 sb.lineplot(x=fpr, y=tpr, color='red', linewidth=1, label='ROC Curve', ax=ax[0])
#     832 ax[0].fill_between(fpr, tpr, facecolor='blue',alpha=0.1)
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1108, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1006 @validate_params(
#    1007     {
#    1008         "y_true": ["array-like"],
#    (...)
#    1017     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1018 ):
#    1019     """Compute Receiver operating characteristic (ROC).
#    1020
#    1021     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1106     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1107     """
# -> 1108     fps, tps, thresholds = _binary_clf_curve(
#    1109         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1110     )
#    1112     # Attempt to drop thresholds corresponding to points in between and
#    1113     # collinear with other points. These are always suboptimal and do not
#    1114     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1119     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1120     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1121     if drop_intermediate and len(fps) > 2:
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:817, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     815 y_type = type_of_target(y_true, input_name="y_true")
#     816 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
# --> 817     raise ValueError("{0} format is not supported".format(y_type))
#     819 check_consistent_length(y_true, y_score, sample_weight)
#     820 y_true = column_or_1d(y_true)
#
# ValueError: multiclass format is not supported
