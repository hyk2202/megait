# %% [markdown]
# # KMeans 모듈화
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
# 연결된 모듈이 업데이트 되면 즉시 자동 로드함
# %load_ext autoreload
# %autoreload 2

from helper.util import *
from helper.plot import *
from helper.analysis import *
from helper.cluster import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of helper.plot failed: Traceback (most recent call last):
#   File "c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\plot.py", line 27, in <module>
#     "AppleGothic" if sys.platform == "darwin" else "Malgun Gothic"
#                      ^^^
# NameError: name 'sys' is not defined
# ]

# %% [markdown]
# ### [2] 데이터 가져오기 + 스케일링

# %%
origin: DataFrame = my_read_excel(path="https://data.hossam.kr/mldata/iris.xlsx", categories=['Species'], info=False)

df = origin.drop(labels='Species', axis=1)
df = my_minmax_scaler(data=df)
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0        0.222222     0.625000      0.067797     0.041667
# 1        0.166667     0.416667      0.067797     0.041667
# 2        0.111111     0.500000      0.050847     0.041667
# 3        0.083333     0.458333      0.084746     0.041667
# 4        0.194444     0.666667      0.067797     0.041667
# ..            ...          ...           ...          ...
# 145      0.666667     0.416667      0.711864     0.916667
# 146      0.555556     0.208333      0.677966     0.750000
# 147      0.611111     0.416667      0.711864     0.791667
# 148      0.527778     0.583333      0.745763     0.916667
# 149      0.444444     0.416667      0.694915     0.708333
#
# [150 rows x 4 columns]

# %% [markdown]
# ## #02. 모듈화 기능 확인 - 단일 군집
#
# ### [1] 단순 군집화

# %%
kmeans = my_single_kmeans(data=df, n_clusters=3)
kmeans.silhouette
# Out:
# 0.48292893354301647

# %% [markdown]
# ### [2] 군집 결과 시각화

# %%
my_cluster_plot(kmeans, df)

# %% [markdown]
# ## #03. 최적 군집 찾기
#
# ### [1] 엘보우 포인트 기준

# %%
my_kmeans(data=df, scoring='e')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 my_kmeans(data=df, scoring='e')
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\cluster.py:386, in my_kmeans(data, n_clusters, init, max_iter, random_state, algorithm, scoring, plot, figsize, dpi)
#     383 if scoring == "elbow" or scoring == "e":
#     384     inertia = [k.inertia_ for k in kmeans_list]
# --> 386     best_k, best_y = my_elbow_point(
#     387         x=cluster_list,
#     388         y=inertia,
#     389         dir="left,down",
#     390         xname="n_cluster",
#     391         yname="inertia",
#     392         title="Elbow Method",
#     393         plot=plot,
#     394         figsize=figsize,
#     395         dpi=dpi,
#     396     )
#     398     best_model = next(filter(lambda x: x.n_clusters == best_k, kmeans_list))
#     399 elif scoring == "silhouette" or scoring == "s":
#
# File c:\Users\hyk\AppData\Local\Programs\Python\Python311\Lib\site-packages\helper\cluster.py:161, in my_elbow_point(x, y, dir, title, xname, yname, S, plot, figsize, dpi)
#     150         ax.axhline(best_y, color="red", linestyle="--", linewidth=0.7)
#     151         ax.text(
#     152             best_x + 0.2,
#     153             best_y + 0.2,
#    (...)
#     158             ha="left",
#     159         )
# --> 161     my_lineplot(
#     162         df=None,
#     163         xname=x,
#     164         yname=y,
#     165         marker="o",
#     166         linewidth=2,
#     167         figsize=figsize,
#     168         dpi=dpi,
#     169         callback=hvline,
#     170     )
#     172 return (best_x, best_y)
#
# TypeError: my_lineplot() got an unexpected keyword argument 'marker'

# %% [markdown]
# ### [2] 실루엣 계수 기준

# %%
my_kmeans(data=df, scoring='s')
# Out:
# KMeans(max_iter=500, n_clusters=2, random_state=0)
