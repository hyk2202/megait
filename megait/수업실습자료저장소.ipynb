# %% [markdown]
# # 메가스터디IT아카데미 산대특 데이터분석 5기
#
# 수업 실습 자료 저장소
#
# ## 설치 패키지
#
# | 패키지 이름 | 설명 |
# |---|---|
# | cx_oracle | Python을 통한 오라클 연동 기능 제공<br/>`Microsoft C++ Build Tools`를 미리 설치해야 함 <!-- <br/> : html 문법으로 줄바꿈표시 -->|
# | sqlalchemy | Python을 통한 데이터베이스 연동 기능 제공(범용) |
# | pandas | 분석용 데이터 구조 및 탐색적 데이터 분석 기능을 제공하는 패키지 |
# | openpyxl | 엑셀 파일 처리 패키지(pandas가 의존함) |
# | xlrd | 엑셀 파일 처리 패키지(pandas가 의존함) |
# | requests | HTTP 요청을 처리하는 패키지 (API연동) |
# | tqdm | Progressbar 구현 패키지 |
# | ipywidgets | tqdm을 jupyter 상에서 동작시키는 패키지 |
# | beautifulsoup4 | HTML 소스코드로부터 컨텐츠 추출 기능 제공 |
# | markdownify | HTML 태그를 markdown으로 변환해 주는 패키지 |
# | selenium | 크롬 브라우저를 제어하는 패키지 |
# | chromedriver_autoinstaller | selenium과 크롬 브라우저를 연결해 주는 chromedirver를 자동으로 설치해 주는 패키지 |
# | yfinance | 야후 파이낸스에서 크롤링하여 주가 데이터를 수집하는 패키지 |
# | pytrends | 구글 트렌드 데이터를 수집하는 패키지 (`requests`, `lxml`, `pandas` 패키지에 의존한다.) |
# | dotenv | 개인정보를 외부 파일에 두고 코드에서는 숨겨주는 패키지 |
# | numpy | 데이터 분석의 근간이 되는 수학, 과학 연산 패키지 |
# | scikit-learn | 파이썬의 가장 대표적인 머신러닝 패키지<br/>`threadpoolctl`, `scipy`, `joblib` 패키지에 의존한다. |
# | imblearn | 머신러닝에서 데이터의 불균형을 해소하기 위한 패키지 |
# | matplotlib | 파이썬의 기본 시각화 패키지 |
# | seaborn | 파이썬의 가장 대중적인 시각화 패키지 |
# | ggplot | R의 가장 대중적인 시각화 패키지. Python에서 사용 가능 |
# | folium | jupyter에 내장 가능한 웹 지도 패키지 |
# | jenkspy | jenks natural breaks 패키지 |
# | scipy | 과학기술 계산을 위한 파이썬 라이브러리. numpy의 상위 라이브러리 |
# | wordcloud | 워드클라우드 시각화 패키지 |
#
# ### Microsoft C++ Build Tools 다운로드
#
# | https://data.hossam.kr/VC_redist.x64.exe
#
# 1. VC_redist.x64 : 별다른 설정 과정 없이 설치 진행
# 2. vs_BuildTools : 체크 항목중 왼쪽 상단의 C++ 관련 항목만 체크하고 진행
#
# ### 패키지 설치 구문
#
# #### 일괄설치
#
# ```cmd
# pip install --upgrade cx_oracle sqlalchemy pandas openpyxl xlrd requests tqdm ipywidgets beautifulsoup4 markdownify selenium chromedriver_autoinstaller yfinance pytrends lxml python-dotenv numpy scikit-learn imblearn matplotlib seaborn ggplot folium jenkspy scipy wordcloud
#
# ```
#
# #### 개별설치
#
# ```cmd
# pip install --upgrade cx_oracle
# pip install --upgrade sqlalchemy
# pip install --upgrade pandas
# pip install --upgrade openpyxl
# pip install --upgrade xlrd
# pip install --upgrade requests
# pip install --upgrade tqdm
# pip install --upgrade ipywidgets
# pip install --upgrade beautifulsoup4
# pip install --upgrade markdownify
# pip install --upgrade selenium
# pip install --upgrade chromedriver_autoinstaller
# pip install --upgrade yfinance
# pip install --upgrade pytrends
# pip install --upgrade lxml
# pip install --upgrade python-dotenv
# pip install --upgrade numpy
# pip install --upgrade scikit-learn
# pip install --upgrade imblearn
# pip install --upgrade matplotlib
# pip install --upgrade seaborn
# pip install --upgrade ggplot
# pip install --upgrade folium
# pip install --upgrade jenkspy
# pip install --upgrade scipy
# pip install --upgrade wordcloud
#
# ```
#
# ```python
# ! pip install --upgrade cx_oracle
# ! pip install --upgrade sqlalchemy
# ! pip install --upgrade pandas
# ! pip install --upgrade openpyxl
# ! pip install --upgrade xlrd
# ! pip install --upgrade requests
# ! pip install --upgrade tqdm
# ! pip install --upgrade ipywidgets
# ! pip install --upgrade beautifulsoup4
# ! pip install --upgrade markdownify
# ! pip install --upgrade selenium
# ! pip install --upgrade chromedriver_autoinstaller
# ! pip install --upgrade yfinance
# ! pip install --upgrade pytrends
# ! pip install --upgrade lxml
# ! pip install --upgrade python-dotenv
# ! pip install --upgrade numpy
# ! pip install --upgrade scikit-learn
# ! pip install --upgrade imblearn
# ! pip install --upgrade matplotlib
# ! pip install --upgrade seaborn
# ! pip install --upgrade ggplot
# ! pip install --upgrade folium
# ! pip install --upgrade jenkspy
# ! pip install --upgrade scipy
# ! pip install --upgrade wordcloud
#
# ```
#
#
# ```python
# pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org pip setuptools
# # 마지막은 python ssl문제가 생겼을때 인증서 등록하는 코드로 일반적으론 안해도 상관없음
# ```
