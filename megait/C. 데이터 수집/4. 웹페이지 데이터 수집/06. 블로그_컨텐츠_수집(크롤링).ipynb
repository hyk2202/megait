# %% [markdown]
# # 블로그 컨텐츠 수집(크롤링)
#
# ## #01. 준비과정
# ### [1] 패키지 참조

# %%
import datetime as dt
import requests
import os
import time
from bs4 import BeautifulSoup
import markdownify as mf
from tqdm.notebook import tqdm

# %% [markdown]
# ## #02. 데이터 요청하기
# ### [1] 세션 생성

# %%
session = requests.Session()

session.headers.update({
    "Referer": "",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
})

# %% [markdown]
# ### [2] 전체 글 목록 가져오기
#
# #### (1) 함수정의

# %%
def getContents(session, url):
    try:
        r = session.get(url)
        
        if r.status_code != 200:
            msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
            raise Exception(msg)
    except Exception as e:
        print("접속에 실패했습니다.")
        print(e)


    r.encoding = "utf-8"
    soup = BeautifulSoup(r.text)

    post = soup.select('.post')
    mydata =[]
    for i, v in enumerate(post):
        # print(v)

        # 하나의 글 안에서 제목 영역을 찾는다.
        entryTitle = v.select(".entry-title a")
        # print(entryTitle)

        # 추출된 요소가 각 게시글 안에서 하나만 존재하므로 `0`번째 원소에 직접 접근한다.
        title = entryTitle[0].text.strip()
        # print(title)

        # 클릭시 이동할 페이지의 주소
        if 'href' in entryTitle[0].attrs:
            href = entryTitle[0].attrs['href']

        # 같은 페이지 내에서 주소 이동할 경우 도메인 생략가능
            
        # 수집된 주소에 도메인이 없다면 덧붙여준다
        if url not in href:
            href = url+href

        else:
            href = None
        # print(href)

        # 작성일
        published = v.select(".published")
        # print(published)
        datetime = published[0].attrs['datetime']
        # print(datetime)
        
        # 요약글
        entryContent = v.select(".entry-content p")
        # print(entryContent)

        # 마지막의 `more` 버튼은 제거한다.
        # entryContent = entryContent[:-1] # python적 접근
        # print(entryContent)

        entryContent = v.select(".entry-content p:not(.read-more)") # CSS적 접근
        # print(entryContent)

        text = ''
        for j, e in enumerate(entryContent): # 2개 이상인 경우도 있으므로 반복문
            text += " " +e.text.strip() if j>0 else e.text.strip()
        # print(text)

        # 태그
        tagLinks = v.select(".tag-links a")
        # print(tagLinks)

        
        for j,e in enumerate(tagLinks):
            tagLinks[j] = e.text.strip()
        
        tags = ','.join(tagLinks)
        
        # 수집된 정보를 하나의 딕셔너리로 묶는다 => 처리방법은 다르게해도 상관 없음
        mydict = {
            "title":title,
            "href":href,
            "datetime":datetime,
            "text":text,
            "tags":tags
        }
        mydata.append(mydict)
    return mydata

# %% [markdown]
# #### (2) 전체 글 목록 수집
# ##### 접근 URL의 패턴과 최대 페이지 수 정의

# %%
url = "https://blog.hossam.kr"
urlFmt = "%s/blog/page{pagenumber}" %url
maxPage = 22

# %% [markdown]
# ##### 글 목록 수집

# %%
blogPosts = []
for i in range(1,maxPage+1):
    targetUrl = urlFmt.format(pagenumber = i) if i>1 else url
    blogPosts += getContents(session,targetUrl)

print("수집된 전체 게시글 수 :",len(blogPosts))
# Out:
# 수집된 전체 게시글 수 : 108

# %% [markdown]
# ### [4] 게시글 별로 상세 내용 가져오기
#
# #### [1] 함수 정의하기

# %%
def getContentBody(session, url):
    domain = "https://blog.hossam.kr"
    try:
        r = session.get(url)
        
        if r.status_code != 200:
            msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
            raise Exception(msg)
    except Exception as e:
        print("접속에 실패했습니다.")
        print(e)

    # 게시글 영역 추출
    r.encoding = "utf-8"
    soup = BeautifulSoup(r.text)
    content = soup.select(".entry-content")[0]
    # 문자열로 변환
    body = str(content)
    # 이미지부분 조정
    
    rebody = body.replace('src="/',f'src="{domain}/')
    # 마크다운으로 변경
    md = mf.markdownify(rebody)
    return md

# %% [markdown]
# #### (3) 활용하기

# %%
dirname = dt.datetime.now().strftime('블로그_글_수집_%y%m%d_%H%M%S')

if not os.path.exists(dirname):
    os.mkdir(dirname)
    
progress = tqdm(total = len(blogPosts))

for i in blogPosts:
    # print(i)
    md = getContentBody(session, i['href'])

    fname = f"{dirname}/{i['datetime']}_{i['title']}.md"
    fname = fname.replace('-','').replace(' ','_')
    
    with open(fname, 'w', encoding='utf-8') as f:
        f.write(md)
    
    print(f"{fname}(이)가 저장되었습니다.")
    progress.update()
    time.sleep(0.1)
# Out:
#   0%|          | 0/108 [00:00<?, ?it/s]
# 블로그_글_수집_231213_161309/20230821_[Toy_Project]_서버_가동_설정_수정.md(이)가 저장되었습니다.
# 블로그_글_수집_231213_161309/20230820_[Toy_Project]_Next.js와_Express_병합.md(이)가 저장되었습니다.
# 블로그_글_수집_231213_161309/20230817_[Toy_Project]_토이_프로젝트_시작.md(이)가 저장되었습니다.
# 블로그_글_수집_231213_161309/20230713_[Mac]_OpenJDK_설치하기.md(이)가 저장되었습니다.
# 블로그_글_수집_231213_161309/20230712_[Mac]_개발환경_구성_필수_요소.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221231_[R]_오픈API_연동__카카오_OpenAPI_연동.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221230_[R]_오픈API_연동__영화_진흥_위원회_박스_오피스_데이터_활용.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221229_[R]_JSON의_이해.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221228_[R]_시계열_분석.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221227_[R]_회귀분석.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221226_[R]_상관분석.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221225_[R]_TTest_가설검정.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221224_[R]_확률과_확률분포.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221223_[R]_추론통계_개요.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221222_[R]_데이터_정제_(2)__이상치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221221_[R]_데이터_정제_(1)__결측치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221220_[R]_변수의_구간화.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221219_[R]_기술통계.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221218_[R]_데이터_변경,_요약.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221217_[R]_데이터_마트_구성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221216_[R]_데이터_전처리.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221215_[R]_데이터시각화(5)_워드클라우드.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221215_[R]_데이터시각화(4)_파이,_산점도_그래프.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221215_[R]_데이터시각화(3)_막대_그래프.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221215_[R]_데이터시각화(2)_선그래프.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221215_[R]_데이터시각화(1)_축,제목_설정.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221215_[R]_데이터_확인하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221214_[R]_패키지의_이해.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221213_[R]_내장함수.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221212_[R]_함수의_이해.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221211_[R]_프로그램_흐름제어_(3)__기본_문법_활용하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221210_[R]_프로그램_흐름제어_(2)__반복문.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221209_[R]_프로그램_흐름제어_(1)__조건문.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221208_[R]_데이터프레임(DataFrame).md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221207_[R]_리스트(List).md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221206_[R]_요인(Factor).md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221205_[R]_행렬(Matrix).md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221204_[R]_벡터(Vector).md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221203_[R]_형식문자.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221202_[R]_변수와_데이터_타입.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221201_[R]_시작하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221101_[R]_데이터_요약.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221031_[R]_데이터_분석_개요.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221030_[R]_통계의_이해.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20221027_[MySQL]_테이블_스키마_기반_POJO_클래스의_멤버변수_선언문_생성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220913_[Ubuntu]_Tomcat9_설치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220912_[Ubuntu]_OpenJDK_설치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220911_[Ubuntu]_Node.js_설치와_백엔드_가동하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220910_[Ubuntu]_MariaDB_설치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220909_[Ubuntu]_SSH_서비스_설정.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220908_[Ubuntu]_FTP_서비스_설치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220907_[Ubuntu]_네트워크와_방화벽.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220906_[Ubuntu]_서비스와_패키지의_이해.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220905_[Ubuntu]_zsh쉘_설치하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220904_[Ubuntu]_시스템의_시작과_종료.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220903_[Ubuntu]_MacOS_Parallels에_우분투_설치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220902_[Ubuntu]_리눅스_설치.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220831_[MySQL]_계정_설정.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220830_[Ubuntu]_CentOS에_SSL_인증서_설치하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220827_[Windows]_특정_포트_방화벽_열기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220826_[Windows]_서비스_등록.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220505_[jQuery]_입력_요소_제어하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220504_[jQuery]_HTML_요소의_탐색과_생성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220503_[jQuery]_HTML_요소_제어.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220502_[jQuery]_이벤트_처리.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220501_[jQuery]_jQuery_시작하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220420_[JS]_JsonServer를_활용한_테스트용_백엔드서버.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220420_[JS]_데이터_읽기,쓰기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220419_[JS]_브라우저_관련_기능.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220418_[JS]_Form_요소.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220416_[JS]_HTML,CSS_제어하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220415_[JS]_이벤트_처리.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220414_[JS]_웹_페이지와_Javascript.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220409_[JS]_정규표현식.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220408_[JS]_Javascript_내장기능.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220407_[JS]_클래스와_객체.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220406_[JS]_함수.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220405_[JS]_JSON.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220404_[JS]_배열.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220403_[JS]_기본문법_활용하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220402_[JS]_프로그램_흐름제어.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220401_[JS]_연산자.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220331_[JS]_변수와_데이터_타입.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220330_[JS]_Javascript_시작하기.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220320_[CSS]_CSS_Flex.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220319_[CSS]_CSS_효과.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220318_[CSS]_background_속성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220317_[CSS]_position_속성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220316_[CSS]_float_속성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220315_[CSS]_display_속성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220314_[CSS]_Margin_속성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220313_[CSS]_박스모델.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220312_[CSS]_문단_관련_속성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220311_[CSS]_폰트_관련_속성.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220310_[CSS]_CSS_시작.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220307_[HTML]_입력요소.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220306_[HTML]_표.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220305_[HTML]_멀티미디어.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220304_[HTML]_문장_관련_요소.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220303_[HTML]_문단_관련_요소.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220302_[HTML]_웹_페이지_기본_구조.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220214_[컴퓨터활용]_Github_사용.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220213_[컴퓨터활용]_Markdown.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220212_[컴퓨터활용]_Mac_기본_활용.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220211_[컴퓨터활용]_Windows_기본_활용.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220210_[컴퓨터활용]_파일_및_디렉토리의_이해.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220201_[컴퓨터활용]_운영체제의_이해.md(이)가 저장되었습니다.
# 접속에 실패했습니다.
# [404 Error] Not Found 에러가 발생함
# 블로그_글_수집_231213_161309/20220101_[Programming]_변수의_토글_처리_기법.md(이)가 저장되었습니다.
